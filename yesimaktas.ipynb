# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e7c27c14-7310-4b15-b1e8-10dba284ac84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7c27c14-7310-4b15-b1e8-10dba284ac84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cities.csv to cities (2).csv

# %%
df=pd.read_csv("cities.csv")
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"  ...   "LonS"   "EW"              "City"  "State"
# 0      41        5       59   "N"  ...        0    "W"        "Youngstown"       OH
# 1      42       52       48   "N"  ...       23    "W"           "Yankton"       SD
# 2      46       35       59   "N"  ...       36    "W"            "Yakima"       WA
# 3      42       16       12   "N"  ...        0    "W"         "Worcester"       MA
# 4      43       37       48   "N"  ...       11    "W"   "Wisconsin Dells"       WI
# ..    ...      ...      ...   ...  ...      ...    ...                 ...      ...
# 123    39       31       12   "N"  ...       35    "W"              "Reno"       NV
# 124    50       25       11   "N"  ...        0    "W"            "Regina"       SA
# 125    40       10       48   "N"  ...       23    "W"         "Red Bluff"       CA
# 126    40       19       48   "N"  ...       48    "W"           "Reading"       PA
# ...

# %%
citiesDataFrame=pd.read_csv("cities.csv", sep=",")
citiesDataFrame.describe()
# Out:
#              LatD      "LatM"      "LatS"      "LonD"      "LonM"      "LonS"
# count  128.000000  128.000000  128.000000  128.000000  128.000000  128.000000
# mean    38.820312   30.765625   27.492188   93.250000   27.742188   26.960938
# std      5.200596   16.426158   18.977814   15.466499   16.927937   18.727807
# min     26.000000    1.000000    0.000000   71.000000    0.000000    0.000000
# 25%     35.000000   16.000000   11.000000   80.000000   14.000000   11.000000
# 50%     39.000000   31.000000   24.000000   89.500000   26.500000   23.500000
# 75%     42.250000   45.000000   47.000000  103.250000   40.250000   47.000000
# max     50.000000   59.000000   59.000000  123.000000   58.000000   59.000000

# %%
citiesDataFrame.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"  ...   "LonS"   "EW"              "City"  "State"
# 0    41        5       59   "N"  ...        0    "W"        "Youngstown"       OH
# 1    42       52       48   "N"  ...       23    "W"           "Yankton"       SD
# 2    46       35       59   "N"  ...       36    "W"            "Yakima"       WA
# 3    42       16       12   "N"  ...        0    "W"         "Worcester"       MA
# 4    43       37       48   "N"  ...       11    "W"   "Wisconsin Dells"       WI
#
# [5 rows x 10 columns]

# %%
citiesDataFrame.hist('LatD')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb42df57b70>]],
#       dtype=object)

# %%
add_row = {'LatD':45, '"LatM"':45, '"LatS"':45,'"NS"':45, '"LonD"':45, '"LonM"':45, '"LonS"':45, '"EW"':'Deneme1', '"City"':'Deneme1', '"State"':'YA'}
citiesDataFrame=citiesDataFrame.append(add_row,ignore_index=True)
citiesDataFrame
# Out:
#      LatD   "LatM"   "LatS"  "NS"  ...  "LonM"  "LonS"  "NS" "State"
# 0      41      5.0     59.0   "N"  ...     NaN     NaN   NaN     NaN
# 1      42     52.0     48.0   "N"  ...     NaN     NaN   NaN     NaN
# 2      46     35.0     59.0   "N"  ...     NaN     NaN   NaN     NaN
# 3      42     16.0     12.0   "N"  ...     NaN     NaN   NaN     NaN
# 4      43     37.0     48.0   "N"  ...     NaN     NaN   NaN     NaN
# ..    ...      ...      ...   ...  ...     ...     ...   ...     ...
# 126    40     19.0     48.0   "N"  ...     NaN     NaN   NaN     NaN
# 127    41      9.0     35.0   "N"  ...     NaN     NaN   NaN     NaN
# 128    45      NaN      NaN   NaN  ...    45.0    45.0  45.0      YA
# 129    45      NaN      NaN   NaN  ...    45.0    45.0  45.0      YA
# 130    45      NaN      NaN   NaN  ...    45.0    45.0  45.0      YA
#
# [131 rows x 19 columns]

# %%
print(citiesDataFrame.drop(45))
# Out:
#      LatD   "LatM"   "LatS"  "NS"  ...  "LonM"  "LonS"  "NS" "State"
# 0      41      5.0     59.0   "N"  ...     NaN     NaN   NaN     NaN
# 1      42     52.0     48.0   "N"  ...     NaN     NaN   NaN     NaN
# 2      46     35.0     59.0   "N"  ...     NaN     NaN   NaN     NaN
# 3      42     16.0     12.0   "N"  ...     NaN     NaN   NaN     NaN
# 4      43     37.0     48.0   "N"  ...     NaN     NaN   NaN     NaN
# ..    ...      ...      ...   ...  ...     ...     ...   ...     ...
# 126    40     19.0     48.0   "N"  ...     NaN     NaN   NaN     NaN
# 127    41      9.0     35.0   "N"  ...     NaN     NaN   NaN     NaN
# 128    45      NaN      NaN   NaN  ...    45.0    45.0  45.0      YA
# 129    45      NaN      NaN   NaN  ...    45.0    45.0  45.0      YA
# 130    45      NaN      NaN   NaN  ...    45.0    45.0  45.0      YA
#
# [130 rows x 19 columns]

# %%
citiesDataFrame.loc[2]
# Out:
# LatD               46
#  "LatM"            35
#  "LatS"            59
#  "NS"             "N"
#  "LonD"           120
#  "LonM"            30
#  "LonS"            36
#  "EW"             "W"
#  "City"      "Yakima"
#  "State"           WA
# "City"            NaN
# "EW"              NaN
# "LatM"            NaN
# "LatS"            NaN
# "LonD"            NaN
# "LonM"            NaN
# "LonS"            NaN
# "NS"              NaN
# "State"           NaN
# Name: 2, dtype: object

# %%
citiesDataFrame.loc[2]=['7','7','7','Y','7','7','7','G','ANTALYA','A','7','7','7','7','7','7','7','7','7']
citiesDataFrame.loc[2]
# Out:
# LatD              7
#  "LatM"           7
#  "LatS"           7
#  "NS"             Y
#  "LonD"           7
#  "LonM"           7
#  "LonS"           7
#  "EW"             G
#  "City"     ANTALYA
#  "State"          A
# "City"            7
# "EW"              7
# "LatM"            7
# "LatS"            7
# "LonD"            7
# "LonM"            7
# "LonS"            7
# "NS"              7
# "State"           7
# Name: 2, dtype: object
